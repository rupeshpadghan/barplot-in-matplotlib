# %%
import matplotlib.pyplot as plt
x=["python","c","c++","java"]
y=[85,60,50,90]
plt.xlabel("LANGUAGE",fontsize=15)
plt.title("IT",fontsize=15)
c=["y","b","m","g"]
plt.bar(x,y,width=0.4,color="y",edgecolor="b",label="populartiy")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
